# %%
import sys
import csv
import tweepy
import matplotlib.pyplot as plt
from IPython import display
import math
from pprint import pprint
import pandas as pd
import numpy as np
import nltk
import re
import matplotlib.pyplot as plt
from collections import Counter
import seaborn as sns
sns.set(style='darkgrid', context='talk', palette='Dark2')

## Twitter credentials
consumer_key = "vXKHnV4JmfMABDdBIo0ZV4H8d"
consumer_secret = "WGD2YXAKjbanj2g0oxjq2wYRRVhOjedtxO3xZSKikSOOIcLIA1"
access_token = "940458986-xOOlmeSvQ4Ws1prLSwjmr8bIZLz5CMwH6HzVOuCm"
access_token_secret = "qfKJZrkqkYJAieoJxQawkFjrGG7YBYQ6N0HDoCOxUr3FR"

## set up an instance of Tweepy
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth)

## search Twitter for something that interests you
query = input("What subject do you want to analyze for this example? \n")
number = input("How many Tweets do you want to analyze? \n")

results = api.search(
   lang="en",
   q=query + " -rt",
   count=number,
   result_type="recent"
)
file_name = 'Twitter_sentiment_download.csv'

with open(file_name, 'w', newline='') as csvfile:
   csv_writer = csv.DictWriter(
       f=csvfile,
       fieldnames=["Tweet", "Sentiment"]
   )
   csv_writer.writeheader()
# Out:
# What subject do you want to analyze for this example?
#  politics
# How many Tweets do you want to analyze?
#  100

# %%
#access data from S3 Bucket
from sagemaker import get_execution_role
role = get_execution_role()
import boto3
s3_client = boto3.client('s3')
data_bucket_name='mishalmf'
obj_list=s3_client.list_objects(Bucket=data_bucket_name)
file=[]
for contents in obj_list['Contents']:
    file.append(contents['Key'])

# %%
twitter = pd.read_csv('s3a://mishalmf/SocialMedia/Twitter_sentiment_download.csv')
twitter.head(3)
# Out:
#                                                Tweet Sentiment
# 0  Trump administration resists global climate ef...   neutral
# 1  "#Politics News: France tells #Trump to stop i...   neutral
# 2  "#POTUS News:  With Nick Ayers out of the runn...   neutral

# %%
from nltk.sentiment.vader import SentimentIntensityAnalyzer as SIA
sia = SIA()
twitter['Tweet']
sentiment = twitter['Tweet'].apply(lambda x : sia.polarity_scores(x))
df=pd.concat([twitter,sentiment.apply(pd.Series)],1)
print(df)
# Out:
#                                                  Tweet Sentiment  compound  \
# 0    Trump administration resists global climate ef...   neutral    0.0000
# 1    "#Politics News: France tells #Trump to stop i...   neutral   -0.2960
# 2    "#POTUS News:  With Nick Ayers out of the runn...   neutral    0.0000
# 3    @tedlieu Not really Ted!\nhttps://t.co/O0HsbgbUbz   neutral    0.0000
# 4    Army queries for Labor MP Pierre Yangs China l...   neutral    0.0000
# 5    Tavis Smiley rips Bill Kristol: You are 'the w...  negative   -0.3400
# 6    Humanism: In gameshow format, politics with tw...   neutral    0.0000
# 7                New Top Hat!\nhttps://t.co/vmxNZt7FV7   neutral    0.2714
# 8    @Crampers1 @rtenews @GerryAdamsSF That's not l...  negative    0.4215
# 9    Who Is Paying for the War in Yemen? - The Atla...   neutral   -0.5994
# 10   @MrAComerford @MelodyHollywood @jackappleby So...   neutral   -0.3612
# 11   FFS! Trump administration resists global clima...   neutral   -0.7027
# 12   @PhillipBoldt @ScotStah @yahuda101 @joanne4864...   neutral    0.0000
# 13   Senate Leaders Unveil Package of Tax Cuts http...   neutral   -0.2960
# 14   It's funny how Libtards don't want conservativ...   neutral   -0.3863
# 15   The numbers dont lie so why arent we doing mor...   neutral    0.0000
# 16   John Kellys exit raises concerns about White H...   neutral   -0.3875
# 17   @AnonOpNOrulers @FindAnotherGear @TheAliceSmit...  negative    0.0000
# 18   Macron The Coward is taking a play from the Am...   neutral   -0.7783
# 19   @DelusionalESG @HoundGrey @SonicFox5000 listen...   neutral    0.0000
# 20   Republicans defend Trump amid brewing legal st...   neutral    0.1280
# 21   @dthur1003 @rickc817 @freedom_moates Trump had...  negative    0.0000
# 22   @realDonaldTrump You tried that line at the UN...  negative    0.2023
# 23   "Nick Ayers, Aide to Pence, Declines Offer to ...   neutral    0.0000
# 24   Russians interacted with at least 14 Trump ass...   neutral    0.0000
# 25   Hewitt is a way better player i said this summ...   neutral    0.2382
# 26   @madisongesiotto Ohio State. Haha. Also, enjoy...  positive    0.7351
# 27   @KamalaHarris I dont care what people look lik...  positive    0.2668
# 28   "Nick Ayers, Aide to Pence, Declines Offer to ...   neutral    0.0000
# 29   TIME TO START FUNDS TO SUPPORT DEMOCRATS RUNNI...   neutral    0.7695
# ..                                                 ...       ...       ...
# 83   The fact is that politics is driving the econo...   neutral    0.0000
# 84   Murphy is human excrement. My Senator.\nhttps:...   neutral    0.0000
# 85   Hitler "aestheticized politics" as a dictator ...   neutral   -0.6808
# 86   Obama Gave Soros-Tied Group $310M to Help Migr...   neutral    0.1280
# 87   @KeithOlbermann Thank you, Keith. This means m...  positive    0.6808
# 88   @LenKasper Without a doubt and politics, what ...  negative    0.2584
# 89   8 of the most influential millennial women in ...   neutral    0.4927
# 90   CSIS cautions Canadian universities about rese...   neutral    0.0000
# 91   @VettingBernie @GotBeachGlass @TheAtlantic @Di...   neutral    0.0000
# 92     He has lost his mind... https://t.co/vL00vLi2tD   neutral   -0.3182
# 93   #TBT: The Amendments they made you memorize @C...   neutral    0.0000
# 94   Texas Republican who helped write state party'...   neutral    0.0000
# 95   This drug saves Americans from opioid overdose...   neutral    0.0000
# 96   @manny_ottawa @eHarmony You never even started...  negative   -0.4215
# 97   Russia finds UN migration pact important for i...   neutral    0.2023
# 98   Run Nick Run:  Nick Ayers, Aide to Pence, Decl...   neutral    0.0000
# 99   No politics  behind Huawei arrest - Trudeau ht...   neutral   -0.5574
# 100  "Nick Ayers, Aide to Pence, Declines Offer to ...   neutral    0.0000
# 101  We need butterflies more than we need walls. #...   neutral    0.0000
# 102  Trump should 'dig in,' \nnot 'give in' when it...   neutral    0.0000
# 103  In North Carolina, per this NYT story, a 77-ye...   neutral   -0.2732
# 104  It is often said that war is a continuation of...   neutral   -0.3506
# 105  Trump administration resists global climate ef...   neutral    0.0000
# 106  @JUCOFFrenzy how some of these guys five stars...   neutral   -0.4633
# 107  But our overwhelming leftist liberal socialist...   neutral    0.5000
# 108  At a certain point, I felt there was a real dr...  negative   -0.5994
# 109  Get money out of politics and profit out of pr...  positive    0.7906
# 110  Report: Rep. Mark Meadows Under Consideration ...   neutral    0.0000
# 111  Mattis Erupts Over Niger Inquiry and Army Revi...   neutral   -0.6808
# 112  ISTORY MADE! First African American woman wins...  positive    0.6114
#
#        neg    neu    pos
# 0    0.000  1.000  0.000
# 1    0.128  0.872  0.000
# 2    0.000  1.000  0.000
# 3    0.000  1.000  0.000
# 4    0.000  1.000  0.000
# 5    0.188  0.688  0.124
# 6    0.000  1.000  0.000
# 7    0.000  0.589  0.411
# 8    0.000  0.798  0.202
# 9    0.281  0.719  0.000
# 10   0.143  0.857  0.000
# 11   0.305  0.695  0.000
# 12   0.000  1.000  0.000
# 13   0.239  0.761  0.000
# 14   0.226  0.655  0.119
# 15   0.000  1.000  0.000
# 16   0.149  0.851  0.000
# 17   0.000  1.000  0.000
# 18   0.346  0.564  0.090
# 19   0.000  1.000  0.000
# 20   0.000  0.824  0.176
# 21   0.000  1.000  0.000
# 22   0.091  0.785  0.124
# 23   0.000  1.000  0.000
# 24   0.000  1.000  0.000
# 25   0.000  0.885  0.115
# 26   0.000  0.563  0.437
# 27   0.198  0.535  0.267
# 28   0.000  1.000  0.000
# 29   0.000  0.730  0.270
# ..     ...    ...    ...
# 83   0.000  1.000  0.000
# 84   0.000  1.000  0.000
# 85   0.259  0.741  0.000
# 86   0.138  0.692  0.170
# 87   0.000  0.772  0.228
# 88   0.059  0.825  0.116
# 89   0.000  0.738  0.262
# 90   0.000  1.000  0.000
# 91   0.000  1.000  0.000
# 92   0.315  0.685  0.000
# 93   0.000  1.000  0.000
# 94   0.000  1.000  0.000
# 95   0.000  1.000  0.000
# 96   0.135  0.865  0.000
# 97   0.000  0.847  0.153
# 98   0.000  1.000  0.000
# 99   0.479  0.521  0.000
# 100  0.000  1.000  0.000
# 101  0.000  1.000  0.000
# 102  0.000  1.000  0.000
# 103  0.104  0.896  0.000
# 104  0.109  0.891  0.000
# 105  0.000  1.000  0.000
# 106  0.137  0.863  0.000
# 107  0.000  0.801  0.199
# 108  0.279  0.637  0.084
# 109  0.000  0.632  0.368
# 110  0.000  1.000  0.000
# 111  0.237  0.763  0.000
# 112  0.000  0.818  0.182
#
# [113 rows x 6 columns]

# %%
df.drop(['Sentiment'], axis=1)
# Out:
#                                                  Tweet  compound    neg  \
# 0    Trump administration resists global climate ef...    0.0000  0.000
# 1    "#Politics News: France tells #Trump to stop i...   -0.2960  0.128
# 2    "#POTUS News:  With Nick Ayers out of the runn...    0.0000  0.000
# 3    @tedlieu Not really Ted!\nhttps://t.co/O0HsbgbUbz    0.0000  0.000
# 4    Army queries for Labor MP Pierre Yangs China l...    0.0000  0.000
# 5    Tavis Smiley rips Bill Kristol: You are 'the w...   -0.3400  0.188
# 6    Humanism: In gameshow format, politics with tw...    0.0000  0.000
# 7                New Top Hat!\nhttps://t.co/vmxNZt7FV7    0.2714  0.000
# 8    @Crampers1 @rtenews @GerryAdamsSF That's not l...    0.4215  0.000
# 9    Who Is Paying for the War in Yemen? - The Atla...   -0.5994  0.281
# 10   @MrAComerford @MelodyHollywood @jackappleby So...   -0.3612  0.143
# 11   FFS! Trump administration resists global clima...   -0.7027  0.305
# 12   @PhillipBoldt @ScotStah @yahuda101 @joanne4864...    0.0000  0.000
# 13   Senate Leaders Unveil Package of Tax Cuts http...   -0.2960  0.239
# 14   It's funny how Libtards don't want conservativ...   -0.3863  0.226
# 15   The numbers dont lie so why arent we doing mor...    0.0000  0.000
# 16   John Kellys exit raises concerns about White H...   -0.3875  0.149
# 17   @AnonOpNOrulers @FindAnotherGear @TheAliceSmit...    0.0000  0.000
# 18   Macron The Coward is taking a play from the Am...   -0.7783  0.346
# 19   @DelusionalESG @HoundGrey @SonicFox5000 listen...    0.0000  0.000
# 20   Republicans defend Trump amid brewing legal st...    0.1280  0.000
# 21   @dthur1003 @rickc817 @freedom_moates Trump had...    0.0000  0.000
# 22   @realDonaldTrump You tried that line at the UN...    0.2023  0.091
# 23   "Nick Ayers, Aide to Pence, Declines Offer to ...    0.0000  0.000
# 24   Russians interacted with at least 14 Trump ass...    0.0000  0.000
# 25   Hewitt is a way better player i said this summ...    0.2382  0.000
# 26   @madisongesiotto Ohio State. Haha. Also, enjoy...    0.7351  0.000
# 27   @KamalaHarris I dont care what people look lik...    0.2668  0.198
# 28   "Nick Ayers, Aide to Pence, Declines Offer to ...    0.0000  0.000
# 29   TIME TO START FUNDS TO SUPPORT DEMOCRATS RUNNI...    0.7695  0.000
# ..                                                 ...       ...    ...
# 83   The fact is that politics is driving the econo...    0.0000  0.000
# 84   Murphy is human excrement. My Senator.\nhttps:...    0.0000  0.000
# 85   Hitler "aestheticized politics" as a dictator ...   -0.6808  0.259
# 86   Obama Gave Soros-Tied Group $310M to Help Migr...    0.1280  0.138
# 87   @KeithOlbermann Thank you, Keith. This means m...    0.6808  0.000
# 88   @LenKasper Without a doubt and politics, what ...    0.2584  0.059
# 89   8 of the most influential millennial women in ...    0.4927  0.000
# 90   CSIS cautions Canadian universities about rese...    0.0000  0.000
# 91   @VettingBernie @GotBeachGlass @TheAtlantic @Di...    0.0000  0.000
# 92     He has lost his mind... https://t.co/vL00vLi2tD   -0.3182  0.315
# 93   #TBT: The Amendments they made you memorize @C...    0.0000  0.000
# 94   Texas Republican who helped write state party'...    0.0000  0.000
# 95   This drug saves Americans from opioid overdose...    0.0000  0.000
# 96   @manny_ottawa @eHarmony You never even started...   -0.4215  0.135
# 97   Russia finds UN migration pact important for i...    0.2023  0.000
# 98   Run Nick Run:  Nick Ayers, Aide to Pence, Decl...    0.0000  0.000
# 99   No politics  behind Huawei arrest - Trudeau ht...   -0.5574  0.479
# 100  "Nick Ayers, Aide to Pence, Declines Offer to ...    0.0000  0.000
# 101  We need butterflies more than we need walls. #...    0.0000  0.000
# 102  Trump should 'dig in,' \nnot 'give in' when it...    0.0000  0.000
# 103  In North Carolina, per this NYT story, a 77-ye...   -0.2732  0.104
# 104  It is often said that war is a continuation of...   -0.3506  0.109
# 105  Trump administration resists global climate ef...    0.0000  0.000
# 106  @JUCOFFrenzy how some of these guys five stars...   -0.4633  0.137
# 107  But our overwhelming leftist liberal socialist...    0.5000  0.000
# 108  At a certain point, I felt there was a real dr...   -0.5994  0.279
# 109  Get money out of politics and profit out of pr...    0.7906  0.000
# 110  Report: Rep. Mark Meadows Under Consideration ...    0.0000  0.000
# 111  Mattis Erupts Over Niger Inquiry and Army Revi...   -0.6808  0.237
# 112  ISTORY MADE! First African American woman wins...    0.6114  0.000
#
#        neu    pos
# 0    1.000  0.000
# 1    0.872  0.000
# 2    1.000  0.000
# 3    1.000  0.000
# 4    1.000  0.000
# 5    0.688  0.124
# 6    1.000  0.000
# 7    0.589  0.411
# 8    0.798  0.202
# 9    0.719  0.000
# 10   0.857  0.000
# 11   0.695  0.000
# 12   1.000  0.000
# 13   0.761  0.000
# 14   0.655  0.119
# 15   1.000  0.000
# 16   0.851  0.000
# 17   1.000  0.000
# 18   0.564  0.090
# 19   1.000  0.000
# 20   0.824  0.176
# 21   1.000  0.000
# 22   0.785  0.124
# 23   1.000  0.000
# 24   1.000  0.000
# 25   0.885  0.115
# 26   0.563  0.437
# 27   0.535  0.267
# 28   1.000  0.000
# 29   0.730  0.270
# ..     ...    ...
# 83   1.000  0.000
# 84   1.000  0.000
# 85   0.741  0.000
# 86   0.692  0.170
# 87   0.772  0.228
# 88   0.825  0.116
# 89   0.738  0.262
# 90   1.000  0.000
# 91   1.000  0.000
# 92   0.685  0.000
# 93   1.000  0.000
# 94   1.000  0.000
# 95   1.000  0.000
# 96   0.865  0.000
# 97   0.847  0.153
# 98   1.000  0.000
# 99   0.521  0.000
# 100  1.000  0.000
# 101  1.000  0.000
# 102  1.000  0.000
# 103  0.896  0.000
# 104  0.891  0.000
# 105  1.000  0.000
# 106  0.863  0.000
# 107  0.801  0.199
# 108  0.637  0.084
# 109  0.632  0.368
# 110  1.000  0.000
# 111  0.763  0.000
# 112  0.818  0.182
#
# [113 rows x 5 columns]

# %%
df['label'] = 0
df.loc[df['compound'] > 0.2, 'label'] = 1
df.loc[df['compound'] < -0.2, 'label'] = -1
df.head()
# Out:
#                                                Tweet Sentiment  compound  \
# 0  Trump administration resists global climate ef...   neutral     0.000
# 1  "#Politics News: France tells #Trump to stop i...   neutral    -0.296
# 2  "#POTUS News:  With Nick Ayers out of the runn...   neutral     0.000
# 3  @tedlieu Not really Ted!\nhttps://t.co/O0HsbgbUbz   neutral     0.000
# 4  Army queries for Labor MP Pierre Yangs China l...   neutral     0.000
#
#      neg    neu  pos  label
# 0  0.000  1.000  0.0      0
# 1  0.128  0.872  0.0     -1
# 2  0.000  1.000  0.0      0
# 3  0.000  1.000  0.0      0
# 4  0.000  1.000  0.0      0

# %%
df2 = df[['Tweet', 'label']]
df2.to_csv('Twitter_Sentiment_analysis_.csv', mode='a', encoding='utf-8', index=False)

# %%
print("Positive Tweets:\n")
pprint(list(df[df['label'] == 1].Tweet)[:5], width=200)

print("\nNegative Tweets:\n")
pprint(list(df[df['label'] == -1].Tweet)[:5], width=200)
# Out:
# Positive Tweets:
#
# ['New Top Hat!\nhttps://t.co/vmxNZt7FV7',
#  "@Crampers1 @rtenews @GerryAdamsSF That's not looking back that's a matter of fact. Those 2 parties continue to abst https://t.co/vf658wasMu",
#  '@realDonaldTrump You tried that line at the UN, and they laughed at you. One legislative package (tax cuts for the https://t.co/7VPwhSMlNP',
#  'Hewitt is a way better player i said this summer but Lee is first round pick politics https://t.co/UyRK44oiN6',
#  '@madisongesiotto Ohio State. Haha. Also, enjoy your perspective covering politics.']
#
# Negative Tweets:
#
# ['"#Politics News: France tells #Trump to stop interfering in its politics - Al Jazeera English #News": https://t.co/iLoYZg7WOO',
#  "Tavis Smiley rips Bill Kristol: You are 'the worst of America' for using Ebola in politics https://t.co/F6uNuLOblu",
#  'Who Is Paying for the War in Yemen? - The Atlantic https://t.co/eiKMmF1aO3',
#  '@MrAComerford @MelodyHollywood @jackappleby So what do you advocate, then? Continuing to ignore the overall emotion https://t.co/a5V0dCkUiU',
#  'FFS! Trump administration resists global climate efforts at home and overseas https://t.co/YFvDt8ViHs']

# %%
print(df.label.value_counts())

print(df.label.value_counts(normalize=True) * 100)
# Out:
#  0    52
#  1    31
# -1    30
# Name: label, dtype: int64
#  0    46.017699
#  1    27.433628
# -1    26.548673
# Name: label, dtype: float64

# %%
counts = df.label.value_counts(normalize=True) * 100

colors = ['grey', 'green', 'red']
labels = 'Neutral', 'Positive', 'Negative'

## use matplotlib to plot the chart
plt.pie(
   x=counts,
   shadow=True,
   colors=colors,
   labels=labels,
   startangle=90,
    autopct = '%i%%'
)


plt.title("Sentiment of Tweets")
plt.show()

# %%
from nltk.tokenize import word_tokenize, RegexpTokenizer

# %%
from nltk.corpus import stopwords
stop_words = stopwords.words('english')

# %%
def remove_pattern(input_txt, pattern):
    r = re.findall(pattern, input_txt)
    for i in r:
        input_txt = re.sub(i, '', input_txt)
        
    return input_txt

# %%
# remove twitter handles (@user)
import re
df['tidy_tweet'] = np.vectorize(remove_pattern)(twitter['Tweet'], "@[\w]*")
df['tidy_tweet'] = np.vectorize(remove_pattern)(twitter['Tweet'], "http[\w]*")
df.head()
# Out:
#                                                Tweet Sentiment  compound  \
# 0  Trump administration resists global climate ef...   neutral     0.000
# 1  "#Politics News: France tells #Trump to stop i...   neutral    -0.296
# 2  "#POTUS News:  With Nick Ayers out of the runn...   neutral     0.000
# 3  @tedlieu Not really Ted!\nhttps://t.co/O0HsbgbUbz   neutral     0.000
# 4  Army queries for Labor MP Pierre Yangs China l...   neutral     0.000
#
#      neg    neu  pos  label                                         tidy_tweet
# 0  0.000  1.000  0.0      0  Trump administration resists global climate ef...
# 1  0.128  0.872  0.0     -1  "#Politics News: France tells #Trump to stop i...
# 2  0.000  1.000  0.0      0  "#POTUS News:  With Nick Ayers out of the runn...
# 3  0.000  1.000  0.0      0       @tedlieu Not really Ted!\n://t.co/O0HsbgbUbz
# 4  0.000  1.000  0.0      0  Army queries for Labor MP Pierre Yangs China l...

# %%
# remove special characters, numbers, punctuations
df['tidy_tweet'] = df['tidy_tweet'].str.replace("[^a-zA-Z#]", " ")
df['tidy_tweet'] = df['tidy_tweet'].apply(lambda x: ' '.join([w for w in x.split() if len(w)>3]))
df.head()
# Out:
#                                                Tweet Sentiment  compound  \
# 0  Trump administration resists global climate ef...   neutral     0.000
# 1  "#Politics News: France tells #Trump to stop i...   neutral    -0.296
# 2  "#POTUS News:  With Nick Ayers out of the runn...   neutral     0.000
# 3  @tedlieu Not really Ted!\nhttps://t.co/O0HsbgbUbz   neutral     0.000
# 4  Army queries for Labor MP Pierre Yangs China l...   neutral     0.000
#
#      neg    neu  pos  label                                         tidy_tweet
# 0  0.000  1.000  0.0      0  Trump administration resists global climate ef...
# 1  0.128  0.872  0.0     -1  #Politics News France tells #Trump stop interf...
# 2  0.000  1.000  0.0      0  #POTUS News With Nick Ayers running #Trump mul...
# 3  0.000  1.000  0.0      0                            tedlieu really HsbgbUbz
# 4  0.000  1.000  0.0      0  Army queries Labor Pierre Yangs China links gm...

# %%
all_words = ' '.join([text for text in df['tidy_tweet']])
from wordcloud import WordCloud
wordcloud = WordCloud(width=800, height=500, random_state=21, max_font_size=110).generate(all_words)

plt.figure(figsize=(10, 7))
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis('off')
plt.show()

# %%
positive_df = df.loc[df['label'] == 1]
# RegEx for stopwords
RE_stopwords = r'\b(?:{})\b'.format('|'.join(stop_words))
# replace '|'-->' ' and drop all stopwords
words = (positive_df.tidy_tweet
           .str.lower()
           .replace([r'\|', RE_stopwords], [' ', ''], regex=True)
           .str.cat(sep=' ')
           .split()
)

positive_dist = nltk.FreqDist(words)
# generate DF out of Counter
rslt = pd.DataFrame(Counter(words).most_common(10),
                    columns=['Word', 'Frequency']).set_index('Word')
print(rslt)

# plot
rslt.plot.bar(rot=0, figsize=(16,10), width=0.8)
# Out:
#                  Frequency
# Word
# politics                 9
# trump                    6
# like                     5
# people                   3
# time                     3
# woman                    3
# matter                   2
# realdonaldtrump          2
# first                    2
# care                     2

# %%
y_val = [x[1] for x in positive_dist.most_common()]

fig = plt.figure(figsize=(10,5))
plt.plot(y_val)

plt.xlabel("Words")
plt.ylabel("Frequency")
plt.title("Word Frequency Distribution (Positive)")
plt.show()

# %%
y_final = []
for i, k, z, t in zip(y_val[0::4], y_val[1::4], y_val[2::4], y_val[3::4]):
    y_final.append(math.log(i + k + z + t))

x_val = [math.log(i + 1) for i in range(len(y_final))]

fig = plt.figure(figsize=(10,5))

plt.xlabel("Words (Log)")
plt.ylabel("Frequency (Log)")
plt.title("Word Frequency Distribution (Positive)")
plt.plot(x_val, y_final)
plt.show()

# %%
negative_df = df.loc[df['label'] == -1]
# RegEx for stopwords
RE_stopwords = r'\b(?:{})\b'.format('|'.join(stop_words))
# replace '|'-->' ' and drop all stopwords
words = (negative_df.tidy_tweet
           .str.lower()
           .replace([r'\|', RE_stopwords], [' ', ''], regex=True)
           .str.cat(sep=' ')
           .split()
)

negative_dist = nltk.FreqDist(words)
# generate DF out of Counter
rslt = pd.DataFrame(Counter(words).most_common(10),
                    columns=['Word', 'Frequency']).set_index('Word')
print(rslt)

# plot
rslt.plot.bar(rot=0, figsize=(16,10), width=0.8)
# Out:
#           Frequency
# Word
# politics         13
# trump             6
# news              3
# stop              2
# using             2
# libtards          2
# house             2
# american          2
# history           2
# without           2

# %%
y_val = [x[1] for x in negative_dist.most_common()]

fig = plt.figure(figsize=(10,5))
plt.plot(y_val)

plt.xlabel("Words")
plt.ylabel("Frequency")
plt.title("Word Frequency Distribution (Negative)")
plt.show()

# %%
y_final = []
for i, k, z in zip(y_val[0::3], y_val[1::3], y_val[2::3]):
    if i + k + z == 0:
        break
    y_final.append(math.log(i + k + z))

x_val = [math.log(i+1) for i in range(len(y_final))]

fig = plt.figure(figsize=(10,5))

plt.xlabel("Words (Log)")
plt.ylabel("Frequency (Log)")
plt.title("Word Frequency Distribution (Negative)")
plt.plot(x_val, y_final)
plt.show()
